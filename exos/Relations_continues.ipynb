# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl

# %%
data = pd.read_csv("data/sales_predictions.csv")
data
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
sns.relplot(x='date', y='item_price', data=data)

# %%
sns.relplot(x='date', y='item_price', data=data.sample(50))

# %%
#fig = mpl.pyplot.figure(figsize=(20, 6))
sns.relplot(x='date', y='item_price', data=data.sample(n=50), height = 10)

# %%
df = pd.DataFrame({'date':pd.to_datetime(data['date']),'item_price': data['item_price']})
df
# Out:
#               date  item_price
# 0       2013-02-01      999.00
# 1       2013-03-01      899.00
# 2       2013-05-01      899.00
# 3       2013-06-01     1709.05
# 4       2013-01-15     1099.00
# ...            ...         ...
# 2935844 2015-10-10      299.00
# 2935845 2015-09-10      299.00
# 2935846 2015-10-14      349.00
# 2935847 2015-10-22      299.00
# 2935848 2015-03-10      299.00
#
# [2935849 rows x 2 columns]

# %%
sns.relplot(x='date', y='item_price', data=data.sample(n=50), height = 10)
